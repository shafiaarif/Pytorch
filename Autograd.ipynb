# %% [markdown]
# # **Why we need Auto differentiation?**

# %% [markdown]
# if i have to wite the program that find the derivative value for any given x,
# y=x**2

# %%
def dy_dx(x):
  return 2*x

# %%
dy_dx(3)
# Out:
# 6

# %% [markdown]
# now if i have
#
# *   y=x**2
# *   z=sin(y)
#
# and i have to find dz/dx, hen it will be the product of dz/dy and dy/dx

# %%
import math
def dz_dx(x):
  return 2 * x * math.cos(x**2)

# %%
dz_dx(2)
# Out:
# -2.6145744834544478

# %% [markdown]
# **As the nested function become more complex, finding their derivatives and then code them become more complex with it.**

# %% [markdown]
# # **Training Process**
#
#
# 1.   **Forward Pass:-** compute the output of the network given an input.
# 2.   **Calculate Loss:-** Calculate the loss function to quantify the error.
#
#
# 1.   **Backward Pass:-** Compute gradients of the loss with respect to parameters.
# 2.   **Update Gradients:-** Adjust the parameters using optimization algorithm (e.g gradient descent).

# %% [markdown]
# # **What is Autograd?**
#   Autograd is a core component of PyTorch that provides automatic differentiation for tensor operations. It enables gradient computation, which is essential for training machine learning models using optimizatin algorithms like gradient descent.

# %% [markdown]
# 1.  *y=x**2*

# %%
import torch

# %%
x=torch.tensor(3.0,requires_grad=True)

# %%
y=x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %% [markdown]
# When we say pytorch that we need gradients by saying rquires_grad=True, PyTorch make a coputation graph internally.
#
# in this case it look like this ( x-----> square------> y ) if it moves in the forward direction then we can find the vaue of y wit the help of x and when we move in the backward direction it should know that which function is used in between to calculate dy/dx that's why it remembered powbackward that there is a power in the backward direction.

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %% [markdown]
# ***2. y=x^2***
#
#   ***z=sin(y)***

# %%
x=torch.tensor(2.0,requires_grad=True)

# %%
y=x**2

# %%
z=torch.sin(y)

# %%
x
# Out:
# tensor(2., requires_grad=True)

# %%
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(-0.7568, grad_fn=<SinBackward0>)

# %% [markdown]
# **Computation graph:-**
#
# **x ----> square ------> y ------> sin -----> z**

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-2.6146)

# %% [markdown]
# ## **Types of Nodes in DAG (Directed Acyclic Graph)**
#
#
# 1.  **Leaf Node:**  Input Nodes
# 2.   **Root Node:** Output Node
# 3.   **Intermediate Nodes:** Middle Nodes

# %% [markdown]
# # Neural Network
# **without Autograd**

# %%
x=torch.tensor(6.7)   # cgpa: 6.7
y=torch.tensor(0.0)   # placement: no

# %%
w=torch.tensor(1.0)
b=torch.tensor(0.0)

# %%
def binary_cross_entropy(prediction,target):
  epsilon=1e-8
  prediction=torch.clamp(prediction,epsilon,1-epsilon)
  return -(target*torch.log(prediction)+(1-target)*torch.log(1-prediction))

# %%
# Forward pass
z=w*x+b                    #weighted sum (linear part)
y_pred=torch.sigmoid(z)    #predicted probability

# compute binary cross entropy loss
loss=binary_cross_entropy(y_pred,y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
# derivation
# 1. dL/d(y_pred) : loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred-y)/ (y_pred*(1-y_pred))

# 2. d(y_pred)/dz : prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz= y_pred * (1-y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw=x
dz_db=1

dL_dw=dloss_dy_pred * dy_pred_dz * dz_dw
dL_db=dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual gradient of loss w.r.t bias (db): {dL_db}")
# Out:
# Manual gradient of loss w.r.t weight (dw): 6.691762447357178
# Manual gradient of loss w.r.t bias (db): 0.998770534992218

# %% [markdown]
# **With Autograd**

# %%
x=torch.tensor(6.7)
y=torch.tensor(0.0)

# %%
w=torch.tensor(1.0,requires_grad=True)
b=torch.tensor(0.0,requires_grad=True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
# forward pass
z=w*x+b
y_pred=torch.sigmoid(z)
print(z)
print(y_pred)
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss=binary_cross_entropy(y_pred,y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %% [markdown]
# # **Autograd with vectors**

# %%
x=torch.tensor([1.0,2.0,3.0],requires_grad=True)

# %%
y=(x**2).mean()

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %% [markdown]
# # **Clearing Gradients**

# %%
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y=x**2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %% [markdown]
# # **How to disable gradient tracking?**
#
#
# 1.   requires_grad_(False)
# 2.   detach()
#
#
# 1.   torch.no_grad()

# %%
x.requires_grad_(False)
x
# Out:
# tensor(2.)

# %%
y=x**2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_10961/1055444503.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     629                 inputs=inputs,
#     630             )
# --> 631         torch.autograd.backward(
#     632             self, gradient, retain_graph, create_graph, inputs=inputs
#     633         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     379     # some Python versions print out the first line of a multi-line function
#     380     # calls in the traceback and some print out the last line
# --> 381     _engine_run_backward(
#     382         tensors,
#     383         grad_tensors_,
#
# ...

# %% [markdown]
# # 2.

# %%
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z=x.detach()

# %%
z
# Out:
# tensor(2.)

# %%
y=x**2
y1=z**2

# %%
y.backward()

# %%
y1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1441/3844781142.py in <cell line: 0>()
# ----> 1 y1.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     629                 inputs=inputs,
#     630             )
# --> 631         torch.autograd.backward(
#     632             self, gradient, retain_graph, create_graph, inputs=inputs
#     633         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     379     # some Python versions print out the first line of a multi-line function
#     380     # calls in the traceback and some print out the last line
# --> 381     _engine_run_backward(
#     382         tensors,
#     383         grad_tensors_,
#
# ...

# %% [markdown]
# # 3.

# %%
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
with torch.no_grad():
  y=x**2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1441/1055444503.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     629                 inputs=inputs,
#     630             )
# --> 631         torch.autograd.backward(
#     632             self, gradient, retain_graph, create_graph, inputs=inputs
#     633         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     379     # some Python versions print out the first line of a multi-line function
#     380     # calls in the traceback and some print out the last line
# --> 381     _engine_run_backward(
#     382         tensors,
#     383         grad_tensors_,
#
# ...
